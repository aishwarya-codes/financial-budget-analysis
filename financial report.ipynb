# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv(r"C:\Users\91884\Downloads\convertcsv.csv")
data.head()
# Out:
#                    Department /Ministry  Fund allotted(in ₹crores)
# 0               MINISTRY OF AGRICULTURE                  131531.19
# 1           DEPARTMENT OF ATOMIC ENERGY                   18264.89
# 2            MINISTRY OF AYURVEDA, YOGA                    2970.30
# 3  MINISTRY OF CHEMICALS AND FERTILISER                   80714.94
# 4            MINISTRY OF CIVIL AVIATION                    3224.67

# %%
  print(data)
# Out:
#                                  Department /Ministry  \
# 0                             MINISTRY OF AGRICULTURE
# 1                         DEPARTMENT OF ATOMIC ENERGY
# 2                          MINISTRY OF AYURVEDA, YOGA
# 3                MINISTRY OF CHEMICALS AND FERTILISER
# 4                          MINISTRY OF CIVIL AVIATION
# 5                                    MINISTRY OF COAL
# 6                   MINISTRY OF COMMERCE AND INDUSTRY
# 7                           MINISTRY OF COMMUNICATION
# 8                        MINISTRY OF CONSUMER AFFAIRS
# 9                       MINISTRY OF CORPORATE AFFAIRS
# 10                                MINISTRY OF CULTURE
# 11                                MINISTRY OF DEFENCE
# 12    MINISTRY OF DEVELOPMENT OF NORTH EASTERN REGION
# 13                         MINISTRY OF EARTH SCIENCES
# 14                              MINISTRY OF EDUCATION
# 15  MINISTRY OF ELECTRONICS AND INFORMATION TECHNO...
# ...

# %%
data.dropna()
# Out:
#                                  Department /Ministry  \
# 0                             MINISTRY OF AGRICULTURE
# 1                         DEPARTMENT OF ATOMIC ENERGY
# 2                          MINISTRY OF AYURVEDA, YOGA
# 3                MINISTRY OF CHEMICALS AND FERTILISER
# 4                          MINISTRY OF CIVIL AVIATION
# 5                                    MINISTRY OF COAL
# 6                   MINISTRY OF COMMERCE AND INDUSTRY
# 7                           MINISTRY OF COMMUNICATION
# 8                        MINISTRY OF CONSUMER AFFAIRS
# 9                       MINISTRY OF CORPORATE AFFAIRS
# 10                                MINISTRY OF CULTURE
# 11                                MINISTRY OF DEFENCE
# 12    MINISTRY OF DEVELOPMENT OF NORTH EASTERN REGION
# 13                         MINISTRY OF EARTH SCIENCES
# 14                              MINISTRY OF EDUCATION
# 15  MINISTRY OF ELECTRONICS AND INFORMATION TECHNO...
# ...

# %%
data = data.iloc[[0,8,11,14,18,23,41,42,43],:]

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
row = {'Department /Ministry': 'OTHERS', 'Fund allotted(in ₹crores)': 592971.0800000001}

# %%
print (data)
# Out:
#                       Department /Ministry  Fund allotted(in ₹crores)
# 0                  MINISTRY OF AGRICULTURE                  131531.19
# 8             MINISTRY OF CONSUMER AFFAIRS                  256948.40
# 11                     MINISTRY OF DEFENCE                  478195.62
# 14                   MINISTRY OF EDUCATION                   93224.31
# 18                     MINISTRY OF FINANCE                 1386273.30
# 23                MINISTRY OF HOME AFFAIRS                  166546.94
# 41                    MINISTRY OF RAILWAYS                  110054.64
# 42  MINISTRY OF ROAD TRANSPORT AND HIGHWAY                  118101.00
# 43           MINISTRY OF RURAL DEVELOPMENT                  133689.50

# %%
print (row)
print(type(row))
# Out:
# {'Department /Ministry': 'OTHERS', 'Fund allotted(in ₹crores)': 592971.0800000001}
# <class 'dict'>

# %%
data = data.reset_index()
print (data)
# Out:
#    level_0  index                    Department /Ministry  \
# 0        0      0                 MINISTRY OF AGRICULTURE
# 1        1      8            MINISTRY OF CONSUMER AFFAIRS
# 2        2     11                     MINISTRY OF DEFENCE
# 3        3     14                   MINISTRY OF EDUCATION
# 4        4     18                     MINISTRY OF FINANCE
# 5        5     23                MINISTRY OF HOME AFFAIRS
# 6        6     41                    MINISTRY OF RAILWAYS
# 7        7     42  MINISTRY OF ROAD TRANSPORT AND HIGHWAY
# 8        8     43           MINISTRY OF RURAL DEVELOPMENT
#
#    Fund allotted(in ₹crores)
# 0                  131531.19
# 1                  256948.40
# 2                  478195.62
# 3                   93224.31
# 4                 1386273.30
# 5                  166546.94
# 6                  110054.64
# 7                  118101.00
# 8                  133689.50

# %%
df_dictionary = pd.DataFrame([row])

# %%
print(df_dictionary)
# Out:
#   Department /Ministry  Fund allotted(in ₹crores)
# 0               OTHERS                  592971.08

# %%
  
frames = [data, df_dictionary]
  
result = pd.concat(frames)
display(result)
# Out:
#    level_0  index                    Department /Ministry  \
# 0      0.0    0.0                 MINISTRY OF AGRICULTURE
# 1      1.0    8.0            MINISTRY OF CONSUMER AFFAIRS
# 2      2.0   11.0                     MINISTRY OF DEFENCE
# 3      3.0   14.0                   MINISTRY OF EDUCATION
# 4      4.0   18.0                     MINISTRY OF FINANCE
# 5      5.0   23.0                MINISTRY OF HOME AFFAIRS
# 6      6.0   41.0                    MINISTRY OF RAILWAYS
# 7      7.0   42.0  MINISTRY OF ROAD TRANSPORT AND HIGHWAY
# 8      8.0   43.0           MINISTRY OF RURAL DEVELOPMENT
# 0      NaN    NaN                                  OTHERS
#
#    Fund allotted(in ₹crores)
# 0                  131531.19
# 1                  256948.40
# 2                  478195.62
# 3                   93224.31
# 4                 1386273.30
# 5                  166546.94
# 6                  110054.64
# 7                  118101.00
# 8                  133689.50
# ...

# %%
data.plot.bar(x='Department /Ministry', y='Fund allotted(in ₹crores)')
# Out:
# <AxesSubplot:xlabel='Department /Ministry'>

# %%
df = data["Fund allotted(in ₹crores)"]
labels = data["Department /Ministry"]
plt.figure(figsize=(7,7))
#autopct displays nables you to display the percent value using Python string formatting
# 
plt.pie(df, labels=labels, autopct='%1.1f%%', startangle=90, pctdistance=0.85, shadow =True)
central_circle = plt.Circle((0, 0), 0.5, color='white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)

#Matplotlib uses matplotlibrc configuration files to customize all kinds of properties,
#which we call 'rc settings' or 'rc parameters'.
plt.rc('font', size=12)
plt.title("Distribution of The Budget", fontsize=20)
plt.show()
# Out:
#   File "C:\Users\91884\AppData\Local\Temp\ipykernel_8212\1649350423.py", line 12
#     which we call 'rc settings' or 'rc parameters'.
#           ^
# SyntaxError: invalid syntax
